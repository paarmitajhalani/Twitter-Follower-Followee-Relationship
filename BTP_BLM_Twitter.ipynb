# %%
import os
import tweepy
import pandas as pd
from json import dump
from json import *
import time

# %%
import wget
from datetime import date
import numpy as np
import csv
from collections import *
import networkx as nx
from networkx import Graph

# %%
import configparser
from tweepy import API, Cursor, OAuthHandler, TweepError
configs = configparser.ConfigParser()
configs.read('./config.ini')
keys = configs['TWITTER']
consumer_key = keys['CONSUMER_KEY'] 
consumer_secret = keys['CONSUMER_SECRET'] 
access_token = keys['ACCESS_TOKEN']
access_secret = keys['ACCESS_SECRET']

# Authenticate Tweepy connection to Twitter API
auth = OAuthHandler(consumer_key, consumer_secret)

auth.set_access_token(access_token, access_secret)
api=tweepy.API(auth)

api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
anticelebTable=[]
for i in protesters:
    
    for j in anticeleb:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            try:
                status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            
                row.append(status[0].following)
            except tweepy.error.TweepError:
                print("user not found")
#             status = api.show_friendship(source_screen_name = i,target_screen_name = j)
#             row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        anticelebTable.append(row)
# Out:
# user not found
# OsopePatrisse LilTunechi ['OsopePatrisse', 'LilTunechi']
# user not found
# OsopePatrisse DojaCat ['OsopePatrisse', 'DojaCat']
# user not found
# OsopePatrisse virgilabloh ['OsopePatrisse', 'virgilabloh']
# user not found
# OsopePatrisse shameikmoore ['OsopePatrisse', 'shameikmoore']
# user not found
# OsopePatrisse llcoolj ['OsopePatrisse', 'llcoolj']
# user not found
# OsopePatrisse terrycrews ['OsopePatrisse', 'terrycrews']
# CharleneCac LilTunechi ['CharleneCac', 'LilTunechi', False]
# CharleneCac DojaCat ['CharleneCac', 'DojaCat', False]
# CharleneCac virgilabloh ['CharleneCac', 'virgilabloh', False]
# CharleneCac shameikmoore ['CharleneCac', 'shameikmoore', False]
# CharleneCac llcoolj ['CharleneCac', 'llcoolj', False]
# CharleneCac terrycrews ['CharleneCac', 'terrycrews', False]
# aliciagarza LilTunechi ['aliciagarza', 'LilTunechi', False]
# aliciagarza DojaCat ['aliciagarza', 'DojaCat', False]
# aliciagarza virgilabloh ['aliciagarza', 'virgilabloh', False]
# ...

# %%
#celebTable=[]
for i in anticeleb:
    
    for j in protesters:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            try:
                status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            
                row.append(status[0].following)
            except tweepy.error.TweepError:
                print("user not found")
#             status = api.show_friendship(source_screen_name = i,target_screen_name = j)
#             row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        anticelebTable.append(row)
# Out:
# user not found
# LilTunechi OsopePatrisse ['LilTunechi', 'OsopePatrisse']
# LilTunechi CharleneCac ['LilTunechi', 'CharleneCac', False]
# LilTunechi aliciagarza ['LilTunechi', 'aliciagarza', False]
# LilTunechi opalayo ['LilTunechi', 'opalayo', False]
# LilTunechi JamilahLemieux ['LilTunechi', 'JamilahLemieux', False]
# LilTunechi ProfessorCrunk ['LilTunechi', 'ProfessorCrunk', False]
# LilTunechi Nettaaaaaaaa ['LilTunechi', 'Nettaaaaaaaa', False]
# LilTunechi brownblaze ['LilTunechi', 'brownblaze', False]
# LilTunechi TheRevAl ['LilTunechi', 'TheRevAl', False]
# LilTunechi jeremiah4north ['LilTunechi', 'jeremiah4north', False]
# LilTunechi kwamerose ['LilTunechi', 'kwamerose', False]
# LilTunechi AalayahEastmond ['LilTunechi', 'AalayahEastmond', False]
# LilTunechi andreaforward8 ['LilTunechi', 'andreaforward8', False]
# LilTunechi nupol_justice ['LilTunechi', 'nupol_justice', False]
# LilTunechi osse2021 ['LilTunechi', 'osse2021', False]
# user not found
# ...

# %%
wokeTable=[]
for i in protesters:
    
    for j in woke:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            try:
                status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            
                row.append(status[0].following)
            except tweepy.error.TweepError:
                print("user not found")
#             status = api.show_friendship(source_screen_name = i,target_screen_name = j)
#             row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        wokeTable.append(row)
# Out:
# user not found
# OsopePatrisse Trevornoah ['OsopePatrisse', 'Trevornoah']
# user not found
# OsopePatrisse jameelajamil ['OsopePatrisse', 'jameelajamil']
# user not found
# OsopePatrisse EmmaWatson ['OsopePatrisse', 'EmmaWatson']
# user not found
# OsopePatrisse Beyonce ['OsopePatrisse', 'Beyonce']
# user not found
# OsopePatrisse johnlegend ['OsopePatrisse', 'johnlegend']
# user not found
# OsopePatrisse chrissyteigen ['OsopePatrisse', 'chrissyteigen']
# user not found
# OsopePatrisse KimKardashian ['OsopePatrisse', 'KimKardashian']
# user not found
# OsopePatrisse iJesseWilliams ['OsopePatrisse', 'iJesseWilliams']
# user not found
# OsopePatrisse KingJames ['OsopePatrisse', 'KingJames']
# user not found
# OsopePatrisse DwyaneWade ['OsopePatrisse', 'DwyaneWade']
# user not found
# OsopePatrisse carmeloanthony ['OsopePatrisse', 'carmeloanthony']
# user not found
# OsopePatrisse CP3 ['OsopePatrisse', 'CP3']
# user not found
# OsopePatrisse IssaRae ['OsopePatrisse', 'IssaRae']
# ...

# %%
#celebTable=[]
for i in woke:
    
    for j in protesters:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            try:
                status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            
                row.append(status[0].following)
            except tweepy.error.TweepError:
                print("user not found")
#             status = api.show_friendship(source_screen_name = i,target_screen_name = j)
#             row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        wokeTable.append(row)
# Out:
# user not found
# Trevornoah OsopePatrisse ['Trevornoah', 'OsopePatrisse']
# Trevornoah CharleneCac ['Trevornoah', 'CharleneCac', False]
# Trevornoah aliciagarza ['Trevornoah', 'aliciagarza', False]
# Trevornoah opalayo ['Trevornoah', 'opalayo', False]
# Trevornoah JamilahLemieux ['Trevornoah', 'JamilahLemieux', False]
# Trevornoah ProfessorCrunk ['Trevornoah', 'ProfessorCrunk', False]
# Trevornoah Nettaaaaaaaa ['Trevornoah', 'Nettaaaaaaaa', False]
# Trevornoah brownblaze ['Trevornoah', 'brownblaze', False]
# Trevornoah TheRevAl ['Trevornoah', 'TheRevAl', False]
# Trevornoah jeremiah4north ['Trevornoah', 'jeremiah4north', False]
# Trevornoah kwamerose ['Trevornoah', 'kwamerose', False]
# Trevornoah AalayahEastmond ['Trevornoah', 'AalayahEastmond', False]
# Trevornoah andreaforward8 ['Trevornoah', 'andreaforward8', False]
# Trevornoah nupol_justice ['Trevornoah', 'nupol_justice', False]
# Trevornoah osse2021 ['Trevornoah', 'osse2021', False]
# user not found
# ...

# %%
df10 = pd.DataFrame(wokeTable, columns = ['Source', 'Target','Follows']) 
 
print(df10)
# Out:
#               Source           Target Follows
# 0      OsopePatrisse       Trevornoah    None
# 1      OsopePatrisse     jameelajamil    None
# 2      OsopePatrisse       EmmaWatson    None
# 3      OsopePatrisse          Beyonce    None
# 4      OsopePatrisse       johnlegend    None
# ..               ...              ...     ...
# 475  TyroneCarter954        kwamerose   False
# 476  TyroneCarter954  AalayahEastmond   False
# 477  TyroneCarter954   andreaforward8   False
# 478  TyroneCarter954    nupol_justice   False
# 479  TyroneCarter954         osse2021   False
#
# [480 rows x 3 columns]

# %%
df10.to_csv('wokeTable.csv')

# %%
celebTable=[]
for i in protesters:
    
    for j in celebrity:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            try:
                status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            
                row.append(status[0].following)
            except tweepy.error.TweepError:
                print("user not found")
#             status = api.show_friendship(source_screen_name = i,target_screen_name = j)
#             row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        celebTable.append(row)
# Out:
# user not found
# OsopePatrisse adamlambert ['OsopePatrisse', 'adamlambert']
# user not found
# OsopePatrisse AROD ['OsopePatrisse', 'AROD']
# user not found
# OsopePatrisse JLo ['OsopePatrisse', 'JLo']
# user not found
# OsopePatrisse ArianaGrande ['OsopePatrisse', 'ArianaGrande']
# user not found
# OsopePatrisse bellahadid ['OsopePatrisse', 'bellahadid']
# user not found
# OsopePatrisse Beyonce ['OsopePatrisse', 'Beyonce']
# user not found
# OsopePatrisse billieeilish ['OsopePatrisse', 'billieeilish']
# user not found
# OsopePatrisse blakelively ['OsopePatrisse', 'blakelively']
# user not found
# OsopePatrisse VancityReynolds ['OsopePatrisse', 'VancityReynolds']
# user not found
# OsopePatrisse colesprouse ['OsopePatrisse', 'colesprouse']
# user not found
# OsopePatrisse Drake ['OsopePatrisse', 'Drake']
# user not found
# OsopePatrisse ImaanHammam ['OsopePatrisse', 'ImaanHammam']
# user not found
# OsopePatrisse Doutzen ['OsopePatrisse', 'Doutzen']
# user not found
# ...

# %%
for i in celebrity:
    
    for j in protesters:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            try:
                status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            
                row.append(status[0].following)
            except tweepy.error.TweepError:
                print("user not found")
#             status = api.show_friendship(source_screen_name = i,target_screen_name = j)
#             row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        celebTable.append(row)
# Out:
# user not found
# adamlambert OsopePatrisse ['adamlambert', 'OsopePatrisse']
# adamlambert CharleneCac ['adamlambert', 'CharleneCac', False]
# adamlambert aliciagarza ['adamlambert', 'aliciagarza', False]
# adamlambert opalayo ['adamlambert', 'opalayo', False]
# adamlambert JamilahLemieux ['adamlambert', 'JamilahLemieux', False]
# adamlambert ProfessorCrunk ['adamlambert', 'ProfessorCrunk', False]
# adamlambert Nettaaaaaaaa ['adamlambert', 'Nettaaaaaaaa', False]
# adamlambert brownblaze ['adamlambert', 'brownblaze', False]
# adamlambert TheRevAl ['adamlambert', 'TheRevAl', False]
# adamlambert jeremiah4north ['adamlambert', 'jeremiah4north', False]
# adamlambert kwamerose ['adamlambert', 'kwamerose', False]
# adamlambert AalayahEastmond ['adamlambert', 'AalayahEastmond', False]
# adamlambert andreaforward8 ['adamlambert', 'andreaforward8', False]
# adamlambert nupol_justice ['adamlambert', 'nupol_justice', False]
# adamlambert osse2021 ['adamlambert', 'osse2021', False]
# ...

# %%
ProtesterTable=[]
for i in protesters:
    
    for j in protesters:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            try:
                status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            
                row.append(status[0].following)
            except tweepy.error.TweepError:
                print("user not found")
#             status = api.show_friendship(source_screen_name = i,target_screen_name = j)
#             row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        ProtesterTable.append(row)
# Out:
# OsopePatrisse OsopePatrisse ['OsopePatrisse']
# user not found
# OsopePatrisse CharleneCac ['OsopePatrisse', 'CharleneCac']
# user not found
# OsopePatrisse aliciagarza ['OsopePatrisse', 'aliciagarza']
# user not found
# OsopePatrisse opalayo ['OsopePatrisse', 'opalayo']
# user not found
# OsopePatrisse JamilahLemieux ['OsopePatrisse', 'JamilahLemieux']
# user not found
# OsopePatrisse ProfessorCrunk ['OsopePatrisse', 'ProfessorCrunk']
# user not found
# OsopePatrisse Nettaaaaaaaa ['OsopePatrisse', 'Nettaaaaaaaa']
# user not found
# OsopePatrisse brownblaze ['OsopePatrisse', 'brownblaze']
# user not found
# OsopePatrisse TheRevAl ['OsopePatrisse', 'TheRevAl']
# user not found
# OsopePatrisse jeremiah4north ['OsopePatrisse', 'jeremiah4north']
# user not found
# OsopePatrisse kwamerose ['OsopePatrisse', 'kwamerose']
# user not found
# OsopePatrisse AalayahEastmond ['OsopePatrisse', 'AalayahEastmond']
# user not found
# OsopePatrisse andreaforward8 ['OsopePatrisse', 'andreaforward8']
# ...

# %%
df7 = pd.DataFrame(ProtesterTable, columns = ['Source', 'Target','Follows']) 
 
print(df7)
# Out:
#             Source           Target Follows
# 0    OsopePatrisse             None    None
# 1    OsopePatrisse      CharleneCac    None
# 2    OsopePatrisse      aliciagarza    None
# 3    OsopePatrisse          opalayo    None
# 4    OsopePatrisse   JamilahLemieux    None
# ..             ...              ...     ...
# 220       osse2021        kwamerose   False
# 221       osse2021  AalayahEastmond   False
# 222       osse2021   andreaforward8   False
# 223       osse2021    nupol_justice   False
# 224       osse2021             None    None
#
# [225 rows x 3 columns]

# %%
df7.to_csv('ProtesterTable.csv')

# %%
mediaTable=[]
for i in protesters:
    
    for j in conservativemedia:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            try:
                status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            
                row.append(status[0].following)
            except tweepy.error.TweepError:
                print("user not found")
#             status = api.show_friendship(source_screen_name = i,target_screen_name = j)
#             row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        mediaTable.append(row)
# Out:
# user not found
# OsopePatrisse glennbeck ['OsopePatrisse', 'glennbeck']
# user not found
# OsopePatrisse seanhannity ['OsopePatrisse', 'seanhannity']
# user not found
# OsopePatrisse BretBaier ['OsopePatrisse', 'BretBaier']
# user not found
# OsopePatrisse DanaPerino ['OsopePatrisse', 'DanaPerino']
# user not found
# OsopePatrisse benshapiro ['OsopePatrisse', 'benshapiro']
# user not found
# OsopePatrisse michaeljknowles ['OsopePatrisse', 'michaeljknowles']
# user not found
# OsopePatrisse RichLowry ['OsopePatrisse', 'RichLowry']
# user not found
# OsopePatrisse kristina_wong ['OsopePatrisse', 'kristina_wong']
# CharleneCac glennbeck ['CharleneCac', 'glennbeck', False]
# CharleneCac seanhannity ['CharleneCac', 'seanhannity', False]
# CharleneCac BretBaier ['CharleneCac', 'BretBaier', False]
# CharleneCac DanaPerino ['CharleneCac', 'DanaPerino', False]
# CharleneCac benshapiro ['CharleneCac', 'benshapiro', False]
# CharleneCac michaeljknowles ['CharleneCac', 'michaeljknowles', False]
# ...

# %%
for i in conservativemedia:
    
    for j in protesters:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            try:
                status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            
                row.append(status[0].following)
            except tweepy.error.TweepError:
                print("user not found")
#             status = api.show_friendship(source_screen_name = i,target_screen_name = j)
#             row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        mediaTable.append(row)
# Out:
# user not found
# glennbeck OsopePatrisse ['glennbeck', 'OsopePatrisse']
# glennbeck CharleneCac ['glennbeck', 'CharleneCac', False]
# glennbeck aliciagarza ['glennbeck', 'aliciagarza', False]
# glennbeck opalayo ['glennbeck', 'opalayo', False]
# glennbeck JamilahLemieux ['glennbeck', 'JamilahLemieux', False]
# glennbeck ProfessorCrunk ['glennbeck', 'ProfessorCrunk', False]
# glennbeck Nettaaaaaaaa ['glennbeck', 'Nettaaaaaaaa', False]
# glennbeck brownblaze ['glennbeck', 'brownblaze', False]
# glennbeck TheRevAl ['glennbeck', 'TheRevAl', False]
# glennbeck jeremiah4north ['glennbeck', 'jeremiah4north', False]
# glennbeck kwamerose ['glennbeck', 'kwamerose', False]
# glennbeck AalayahEastmond ['glennbeck', 'AalayahEastmond', False]
# glennbeck andreaforward8 ['glennbeck', 'andreaforward8', False]
# glennbeck nupol_justice ['glennbeck', 'nupol_justice', False]
# glennbeck osse2021 ['glennbeck', 'osse2021', False]
# user not found
# ...

# %%
for i in liberalmedia:
    
    for j in protesters:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            try:
                status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            
                row.append(status[0].following)
            except tweepy.error.TweepError:
                print("user not found")
#             status = api.show_friendship(source_screen_name = i,target_screen_name = j)
#             row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        mediaTable.append(row)
# Out:
# user not found
# benyt OsopePatrisse ['benyt', 'OsopePatrisse']
# benyt CharleneCac ['benyt', 'CharleneCac', False]
# benyt aliciagarza ['benyt', 'aliciagarza', False]
# benyt opalayo ['benyt', 'opalayo', False]
# benyt JamilahLemieux ['benyt', 'JamilahLemieux', False]
# benyt ProfessorCrunk ['benyt', 'ProfessorCrunk', False]
# benyt Nettaaaaaaaa ['benyt', 'Nettaaaaaaaa', False]
# benyt brownblaze ['benyt', 'brownblaze', False]
# benyt TheRevAl ['benyt', 'TheRevAl', True]
# benyt jeremiah4north ['benyt', 'jeremiah4north', False]
# benyt kwamerose ['benyt', 'kwamerose', False]
# benyt AalayahEastmond ['benyt', 'AalayahEastmond', False]
# benyt andreaforward8 ['benyt', 'andreaforward8', False]
# benyt nupol_justice ['benyt', 'nupol_justice', False]
# benyt osse2021 ['benyt', 'osse2021', False]
# user not found
# OmarJimenez OsopePatrisse ['OmarJimenez', 'OsopePatrisse']
# OmarJimenez CharleneCac ['OmarJimenez', 'CharleneCac', False]
# ...

# %%
for i in conservativemedia:
    
    for j in liberalmedia:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            try:
                status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            
                row.append(status[0].following)
            except tweepy.error.TweepError:
                print("user not found")
#             status = api.show_friendship(source_screen_name = i,target_screen_name = j)
#             row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        mediaTable.append(row)
# Out:
# glennbeck benyt ['glennbeck', 'benyt', False]
# glennbeck OmarJimenez ['glennbeck', 'OmarJimenez', False]
# glennbeck FareedZakaria ['glennbeck', 'FareedZakaria', False]
# glennbeck deanbaquet ['glennbeck', 'deanbaquet', False]
# glennbeck alexisjreports ['glennbeck', 'alexisjreports', False]
# glennbeck search4swag ['glennbeck', 'search4swag', False]
# glennbeck ZoeTillman ['glennbeck', 'ZoeTillman', False]
# glennbeck kyledcheney ['glennbeck', 'kyledcheney', False]
# glennbeck seungminkim ['glennbeck', 'seungminkim', False]
# glennbeck sahilkapur ['glennbeck', 'sahilkapur', False]
# glennbeck jeneps ['glennbeck', 'jeneps', False]
# seanhannity benyt ['seanhannity', 'benyt', False]
# seanhannity OmarJimenez ['seanhannity', 'OmarJimenez', False]
# seanhannity FareedZakaria ['seanhannity', 'FareedZakaria', False]
# seanhannity deanbaquet ['seanhannity', 'deanbaquet', False]
# seanhannity alexisjreports ['seanhannity', 'alexisjreports', False]
# ...

# %%
for i in liberalmedia:
    
    for j in conservativemedia:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            try:
                status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            
                row.append(status[0].following)
            except tweepy.error.TweepError:
                print("user not found")
#             status = api.show_friendship(source_screen_name = i,target_screen_name = j)
#             row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        mediaTable.append(row)
# Out:
# benyt glennbeck ['benyt', 'glennbeck', True]
# benyt seanhannity ['benyt', 'seanhannity', True]
# benyt BretBaier ['benyt', 'BretBaier', True]
# benyt DanaPerino ['benyt', 'DanaPerino', True]
# benyt benshapiro ['benyt', 'benshapiro', True]
# benyt michaeljknowles ['benyt', 'michaeljknowles', False]
# benyt RichLowry ['benyt', 'RichLowry', True]
# benyt kristina_wong ['benyt', 'kristina_wong', False]
# OmarJimenez glennbeck ['OmarJimenez', 'glennbeck', False]
# OmarJimenez seanhannity ['OmarJimenez', 'seanhannity', False]
# OmarJimenez BretBaier ['OmarJimenez', 'BretBaier', True]
# OmarJimenez DanaPerino ['OmarJimenez', 'DanaPerino', False]
# OmarJimenez benshapiro ['OmarJimenez', 'benshapiro', False]
# OmarJimenez michaeljknowles ['OmarJimenez', 'michaeljknowles', False]
# OmarJimenez RichLowry ['OmarJimenez', 'RichLowry', False]
# OmarJimenez kristina_wong ['OmarJimenez', 'kristina_wong', False]
# FareedZakaria glennbeck ['FareedZakaria', 'glennbeck', True]
# ...

# %%
#leftleftTable=[]
for i in protesters:
    
    for j in liberalmedia:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            try:
                status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            
                row.append(status[0].following)
            except tweepy.error.TweepError:
                print("user not found")
#             status = api.show_friendship(source_screen_name = i,target_screen_name = j)
#             row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        mediaTable.append(row)
# Out:
# user not found
# OsopePatrisse benyt ['OsopePatrisse', 'benyt']
# user not found
# OsopePatrisse OmarJimenez ['OsopePatrisse', 'OmarJimenez']
# user not found
# OsopePatrisse FareedZakaria ['OsopePatrisse', 'FareedZakaria']
# user not found
# OsopePatrisse deanbaquet ['OsopePatrisse', 'deanbaquet']
# user not found
# OsopePatrisse alexisjreports ['OsopePatrisse', 'alexisjreports']
# user not found
# OsopePatrisse search4swag ['OsopePatrisse', 'search4swag']
# user not found
# OsopePatrisse ZoeTillman ['OsopePatrisse', 'ZoeTillman']
# user not found
# OsopePatrisse kyledcheney ['OsopePatrisse', 'kyledcheney']
# user not found
# OsopePatrisse seungminkim ['OsopePatrisse', 'seungminkim']
# user not found
# OsopePatrisse sahilkapur ['OsopePatrisse', 'sahilkapur']
# user not found
# OsopePatrisse jeneps ['OsopePatrisse', 'jeneps']
# CharleneCac benyt ['CharleneCac', 'benyt', False]
# CharleneCac OmarJimenez ['CharleneCac', 'OmarJimenez', False]
# ...

# %%
df6 = pd.DataFrame(mediaTable, columns = ['Source', 'Target','Follows']) 
 
print(df6)
# Out:
#             Source       Target Follows
# 0    OsopePatrisse    glennbeck    None
# 1    OsopePatrisse  seanhannity    None
# 2    OsopePatrisse    BretBaier    None
# 3    OsopePatrisse   DanaPerino    None
# 4    OsopePatrisse   benshapiro    None
# ..             ...          ...     ...
# 741  kristina_wong   ZoeTillman   False
# 742  kristina_wong  kyledcheney   False
# 743  kristina_wong  seungminkim   False
# 744  kristina_wong   sahilkapur   False
# 745  kristina_wong       jeneps   False
#
# [746 rows x 3 columns]

# %%
df6.to_csv('mediaTable.csv')

# %%
leftleftTable=[]
for i in protesters:
    
    for j in nonantagonist:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            try:
                status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            
                row.append(status[0].following)
            except tweepy.error.TweepError:
                print("user not found")
#             status = api.show_friendship(source_screen_name = i,target_screen_name = j)
#             row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        leftleftTable.append(row)
    #matrix.append([0 for c in range(0, cols)])
# Out:
# user not found
# OsopePatrisse POTUS ['OsopePatrisse', 'POTUS']
# user not found
# OsopePatrisse VP ['OsopePatrisse', 'VP']
# user not found
# OsopePatrisse BarackObama ['OsopePatrisse', 'BarackObama']
# CharleneCac POTUS ['CharleneCac', 'POTUS', False]
# CharleneCac VP ['CharleneCac', 'VP', False]
# CharleneCac BarackObama ['CharleneCac', 'BarackObama', False]
# aliciagarza POTUS ['aliciagarza', 'POTUS', True]
# aliciagarza VP ['aliciagarza', 'VP', True]
# aliciagarza BarackObama ['aliciagarza', 'BarackObama', True]
# opalayo POTUS ['opalayo', 'POTUS', False]
# opalayo VP ['opalayo', 'VP', True]
# opalayo BarackObama ['opalayo', 'BarackObama', True]
# JamilahLemieux POTUS ['JamilahLemieux', 'POTUS', True]
# JamilahLemieux VP ['JamilahLemieux', 'VP', True]
# JamilahLemieux BarackObama ['JamilahLemieux', 'BarackObama', True]
# ProfessorCrunk POTUS ['ProfessorCrunk', 'POTUS', True]
# ProfessorCrunk VP ['ProfessorCrunk', 'VP', True]
# ...

# %%
for i in nonantagonist:
    
    for j in protesters:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            try:
                status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            
                row.append(status[0].following)
            except tweepy.error.TweepError:
                print("user not found")
#             status = api.show_friendship(source_screen_name = i,target_screen_name = j)
#             row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        leftleftTable.append(row)
# Out:
# user not found
# POTUS OsopePatrisse ['POTUS', 'OsopePatrisse']
# POTUS CharleneCac ['POTUS', 'CharleneCac', False]
# POTUS aliciagarza ['POTUS', 'aliciagarza', False]
# POTUS opalayo ['POTUS', 'opalayo', False]
# POTUS JamilahLemieux ['POTUS', 'JamilahLemieux', False]
# POTUS ProfessorCrunk ['POTUS', 'ProfessorCrunk', False]
# POTUS Nettaaaaaaaa ['POTUS', 'Nettaaaaaaaa', False]
# POTUS brownblaze ['POTUS', 'brownblaze', False]
# POTUS TheRevAl ['POTUS', 'TheRevAl', False]
# POTUS jeremiah4north ['POTUS', 'jeremiah4north', False]
# POTUS kwamerose ['POTUS', 'kwamerose', False]
# POTUS AalayahEastmond ['POTUS', 'AalayahEastmond', False]
# POTUS andreaforward8 ['POTUS', 'andreaforward8', False]
# POTUS nupol_justice ['POTUS', 'nupol_justice', False]
# POTUS osse2021 ['POTUS', 'osse2021', False]
# user not found
# VP OsopePatrisse ['VP', 'OsopePatrisse']
# VP CharleneCac ['VP', 'CharleneCac', False]
# VP aliciagarza ['VP', 'aliciagarza', False]
# VP opalayo ['VP', 'opalayo', False]
# ...

# %%
df5 = pd.DataFrame(leftleftTable, columns = ['Source', 'Target','Follows']) 
 
print(df5 )
# Out:
#            Source           Target Follows
# 0   OsopePatrisse            POTUS    None
# 1   OsopePatrisse               VP    None
# 2   OsopePatrisse      BarackObama    None
# 3     CharleneCac            POTUS   False
# 4     CharleneCac               VP   False
# ..            ...              ...     ...
# 85    BarackObama        kwamerose   False
# 86    BarackObama  AalayahEastmond   False
# 87    BarackObama   andreaforward8   False
# 88    BarackObama    nupol_justice   False
# 89    BarackObama         osse2021   False
#
# [90 rows x 3 columns]

# %%
df5.to_csv('left_left.csv')

# %%
df9.to_csv('celeb.csv')

# %%
df9 = pd.DataFrame(celebTable, columns = ['Source', 'Target','Follows']) 
 
print(df9 )
# Out:
#             Source           Target Follows
# 0    OsopePatrisse      adamlambert    None
# 1    OsopePatrisse             AROD    None
# 2    OsopePatrisse              JLo    None
# 3    OsopePatrisse     ArianaGrande    None
# 4    OsopePatrisse       bellahadid    None
# ..             ...              ...     ...
# 685        Madonna        kwamerose   False
# 686        Madonna  AalayahEastmond   False
# 687        Madonna   andreaforward8   False
# 688        Madonna    nupol_justice   False
# 689        Madonna         osse2021   False
#
# [690 rows x 3 columns]

# %%
politicsTable=[]
for i in antagonist:
    
    for j in nonantagonist:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        politicsTable.append(row)
    #matrix.append([0 for c in range(0, cols)])
# Out:
# realDonaldTrump AOC ['realDonaldTrump', 'AOC', False]
# realDonaldTrump CarterCenter ['realDonaldTrump', 'CarterCenter', False]
# realDonaldTrump BernieSanders ['realDonaldTrump', 'BernieSanders', False]
# realDonaldTrump JoeBiden ['realDonaldTrump', 'JoeBiden', False]
# realDonaldTrump KamalaHarris ['realDonaldTrump', 'KamalaHarris', False]
# realDonaldTrump SenWarren ['realDonaldTrump', 'SenWarren', False]
# realDonaldTrump RepCummings ['realDonaldTrump', 'RepCummings', False]
# realDonaldTrump repjohnlewis ['realDonaldTrump', 'repjohnlewis', False]
# realDonaldTrump HillaryClinton ['realDonaldTrump', 'HillaryClinton', False]
# realDonaldTrump NYGovCuomo ['realDonaldTrump', 'NYGovCuomo', False]
# realDonaldTrump Mike_Pence ['realDonaldTrump', 'Mike_Pence', False]
# realDonaldTrump JohnKerry ['realDonaldTrump', 'JohnKerry', False]
# realDonaldTrump RepMaxineWaters ['realDonaldTrump', 'RepMaxineWaters', False]
# ...

# %%
#politicsTable=[]
for i in nonantagonist:
    
    for j in antagonist:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        politicsTable.append(row)
    #matrix.append([0 for c in range(0, cols)])
# Out:
# AOC realDonaldTrump ['AOC', 'realDonaldTrump', False]
# AOC jdanbishop ['AOC', 'jdanbishop', False]
# AOC Schwarzenegger ['AOC', 'Schwarzenegger', True]
# AOC SecretaryCarson ['AOC', 'SecretaryCarson', False]
# AOC tedcruz ['AOC', 'tedcruz', False]
# AOC BorisJohnson ['AOC', 'BorisJohnson', False]
# AOC RudyGiuliani ['AOC', 'RudyGiuliani', False]
# AOC GOPLeader ['AOC', 'GOPLeader', False]
# AOC SenatorTimScott ['AOC', 'SenatorTimScott', False]
# AOC RepJuanFBarquin ['AOC', 'RepJuanFBarquin', False]
# AOC GovRonDeSantis ['AOC', 'GovRonDeSantis', False]
# AOC mtgreenee ['AOC', 'mtgreenee', False]
# AOC SaraJacobsCA ['AOC', 'SaraJacobsCA', True]
# AOC RepMattGaetz ['AOC', 'RepMattGaetz', False]
# CarterCenter realDonaldTrump ['CarterCenter', 'realDonaldTrump', False]
# CarterCenter jdanbishop ['CarterCenter', 'jdanbishop', False]
# CarterCenter Schwarzenegger ['CarterCenter', 'Schwarzenegger', False]
# CarterCenter SecretaryCarson ['CarterCenter', 'SecretaryCarson', False]
# ...

# %%
for i in antagonist:
    
    for j in antagonist:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        politicsTable.append(row)
    #matrix.append([0 for c in range(0, cols)])
# Out:
# realDonaldTrump realDonaldTrump ['realDonaldTrump']
# realDonaldTrump jdanbishop ['realDonaldTrump', 'jdanbishop', False]
# realDonaldTrump Schwarzenegger ['realDonaldTrump', 'Schwarzenegger', False]
# realDonaldTrump SecretaryCarson ['realDonaldTrump', 'SecretaryCarson', False]
# realDonaldTrump tedcruz ['realDonaldTrump', 'tedcruz', False]
# realDonaldTrump BorisJohnson ['realDonaldTrump', 'BorisJohnson', False]
# realDonaldTrump RudyGiuliani ['realDonaldTrump', 'RudyGiuliani', False]
# realDonaldTrump GOPLeader ['realDonaldTrump', 'GOPLeader', False]
# realDonaldTrump SenatorTimScott ['realDonaldTrump', 'SenatorTimScott', False]
# realDonaldTrump RepJuanFBarquin ['realDonaldTrump', 'RepJuanFBarquin', False]
# realDonaldTrump GovRonDeSantis ['realDonaldTrump', 'GovRonDeSantis', False]
# realDonaldTrump mtgreenee ['realDonaldTrump', 'mtgreenee', False]
# realDonaldTrump SaraJacobsCA ['realDonaldTrump', 'SaraJacobsCA', False]
# ...

# %%
for i in nonantagonist:
    
    for j in nonantagonist:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        politicsTable.append(row)
    #matrix.append([0 for c in range(0, cols)])
# Out:
# AOC AOC ['AOC']
# AOC CarterCenter ['AOC', 'CarterCenter', False]
# AOC BernieSanders ['AOC', 'BernieSanders', True]
# AOC JoeBiden ['AOC', 'JoeBiden', True]
# AOC KamalaHarris ['AOC', 'KamalaHarris', True]
# AOC SenWarren ['AOC', 'SenWarren', True]
# AOC RepCummings ['AOC', 'RepCummings', True]
# AOC repjohnlewis ['AOC', 'repjohnlewis', True]
# AOC HillaryClinton ['AOC', 'HillaryClinton', True]
# AOC NYGovCuomo ['AOC', 'NYGovCuomo', True]
# AOC Mike_Pence ['AOC', 'Mike_Pence', False]
# AOC JohnKerry ['AOC', 'JohnKerry', False]
# AOC RepMaxineWaters ['AOC', 'RepMaxineWaters', True]
# AOC SpeakerPelosi ['AOC', 'SpeakerPelosi', True]
# AOC MayorBowser ['AOC', 'MayorBowser', False]
# AOC MurielBowser ['AOC', 'MurielBowser', False]
# AOC Jacob_Frey ['AOC', 'Jacob_Frey', False]
# AOC GovTimWalz ['AOC', 'GovTimWalz', False]
# AOC MayorHancock ['AOC', 'MayorHancock', False]
# AOC IlhanMN ['AOC', 'IlhanMN', True]
# AOC SenAmyKlobuchar ['AOC', 'SenAmyKlobuchar', False]
# ...

# %%
df4 = pd.DataFrame(politicsTable, columns = ['Source', 'Target','Follows']) 
 
print(df4 )
# Out:
#                Source         Target Follows
# 0     realDonaldTrump            AOC   False
# 1     realDonaldTrump   CarterCenter   False
# 2     realDonaldTrump  BernieSanders   False
# 3     realDonaldTrump       JoeBiden   False
# 4     realDonaldTrump   KamalaHarris   False
# ...               ...            ...     ...
# 1595      BarackObama   SenTinaSmith   False
# 1596      BarackObama  andreajenkyns   False
# 1597      BarackObama          POTUS   False
# 1598      BarackObama             VP   False
# 1599      BarackObama           None    None
#
# [1600 rows x 3 columns]

# %%
df4.to_csv('Politics_Table_Final.csv')

# %%
df3 = pd.DataFrame(politicsTable, columns = ['Source', 'Target','Follows']) 
 
print(df3 )
# Out:
#               Source           Target  Follows
# 0    realDonaldTrump              AOC    False
# 1    realDonaldTrump     CarterCenter    False
# 2    realDonaldTrump    BernieSanders    False
# 3    realDonaldTrump         JoeBiden    False
# 4    realDonaldTrump     KamalaHarris    False
# ..               ...              ...      ...
# 723      BarackObama  RepJuanFBarquin    False
# 724      BarackObama   GovRonDeSantis    False
# 725      BarackObama        mtgreenee    False
# 726      BarackObama     SaraJacobsCA    False
# 727      BarackObama     RepMattGaetz    False
#
# [728 rows x 3 columns]

# %%
df3.to_csv('Politics_Table.csv')

# %%
coord=defaultdict(lambda: defaultdict(list))

# %%
inp=input()
"""
@OsopePatrisse
@CharleneCac
@aliciagarza
@opalayo
@JamilahLemieux
@ProfessorCrunk
@Nettaaaaaaaa
@brownblaze
@TheRevAl
@jeremiah4north
@kwamerose
@AalayahEastmond
@andreaforward8
@nupol_justice
@osse2021

"""
# @vemula_radhika
# @BhimArmyChief
# @kanhaiyakumar
# @jigneshmevani80
# @UmarKhalidJNU
# @smudgal
# @tmkrishna
# @kunalkamra88
# @DSBindra4
# @Apoorvanand__
# @irenaakbar
# @rainamk1
# @indersalim
# @KushaKapila
# @ShabnamHashmi
# @sadafjafar
# @pbhushan1
# @AyshaRenna
# @_imaams
# @ShashiTharoor

# """
# Out:
# @OsopePatrisse @CharleneCac @aliciagarza @opalayo @JamilahLemieux @ProfessorCrunk @Nettaaaaaaaa @brownblaze @TheRevAl @jeremiah4north @kwamerose @AalayahEastmond @andreaforward8 @nupol_justice @osse2021
# '\n@OsopePatrisse\n@CharleneCac\n@aliciagarza\n@opalayo\n@JamilahLemieux\n@ProfessorCrunk\n@Nettaaaaaaaa\n@brownblaze\n@TheRevAl\n@jeremiah4north\n@kwamerose\n@AalayahEastmond\n@andreaforward8\n@nupol_justice\n@osse2021\n\n'

# %%
inp=input()
"""
@adamlambert
@AROD
@JLo
@ArianaGrande
@bellahadid
@Beyonce
@billieeilish
@blakelively
@VancityReynolds
@colesprouse
@Drake
@ImaanHammam
@Doutzen
@GiGiHadid
@halsey
@Harry_Styles
@RossLynch
@JazSinclair
@joejonas
@LaurenJauregui
@lilireinhart
@machinegunkelly
@Madonna

"""
# Out:
# @adamlambert @AROD @JLo @ArianaGrande @bellahadid @Beyonce @billieeilish @blakelively @VancityReynolds @colesprouse @Drake @ImaanHammam @Doutzen @GiGiHadid @halsey @Harry_Styles @RossLynch @JazSinclair @joejonas @LaurenJauregui @lilireinhart @machinegunkelly @Madonna
# '\n@adamlambert\n@AROD\n@JLo\n@ArianaGrande\n@bellahadid\n@Beyonce\n@billieeilish\n@blakelively\n@VancityReynolds\n@colesprouse\n@Drake\n@ImaanHammam\n@Doutzen\n@GiGiHadid\n@halsey\n@Harry_Styles\n@RossLynch\n@JazSinclair\n@joejonas\n@LaurenJauregui\n@lilireinhart\n@machinegunkelly\n@Madonna\n\n'

# %%
inp=input()
"""
@benyt
@OmarJimenez
@FareedZakaria
@deanbaquet
@alexisjreports
@search4swag
@ZoeTillman
@kyledcheney
@seungminkim
@sahilkapur
@jeneps

"""
# Out:
# @benyt @OmarJimenez @FareedZakaria @deanbaquet @alexisjreports @search4swag @ZoeTillman @kyledcheney @seungminkim @sahilkapur @jeneps
# '\n@benyt\n@OmarJimenez\n@FareedZakaria\n@deanbaquet\n@alexisjreports\n@search4swag\n@ZoeTillman\n@kyledcheney\n@seungminkim\n@sahilkapur\n@jeneps\n\n'

# %%
inp=input()
"""
@Trevornoah
@jameelajamil
@EmmaWatson
@Beyonce
@johnlegend
@chrissyteigen
@KimKardashian
@iJesseWilliams
@KingJames
@DwyaneWade
@carmeloanthony
@CP3
@IssaRae
@kanyewest
@Kaepernick7
@TyroneCarter954

"""
# Out:
# @Trevornoah @jameelajamil @EmmaWatson @Beyonce @johnlegend @chrissyteigen @KimKardashian @iJesseWilliams @KingJames @DwyaneWade @carmeloanthony @CP3 @IssaRae @kanyewest @Kaepernick7 @TyroneCarter954
# '\n@Trevornoah\n@jameelajamil\n@EmmaWatson\n@Beyonce\n@johnlegend\n@chrissyteigen\n@KimKardashian\n@iJesseWilliams\n@KingJames\n@DwyaneWade\n@carmeloanthony\n@CP3\n@IssaRae\n@kanyewest\n@Kaepernick7\n@TyroneCarter954\n\n'

# %%
inp=input()
"""
@LilTunechi
@DojaCat
@virgilabloh
@shameikmoore
@llcoolj
@terrycrews

@glennbeck
@seanhannity
@BretBaier
@DanaPerino
@benshapiro
@michaeljknowles
@RichLowry
@kristina_wong

"""
# Out:
# @LilTunechi @DojaCat @virgilabloh @shameikmoore @llcoolj @terrycrews
# '\n@LilTunechi\n@DojaCat\n@virgilabloh\n@shameikmoore\n@llcoolj\n@terrycrews\n\n@glennbeck\n@seanhannity\n@BretBaier\n@DanaPerino\n@benshapiro\n@michaeljknowles\n@RichLowry\n@kristina_wong\n\n'

# %%
anticeleb=inp.split()
anticeleb = [x if x[0]!="@" else x[1:] for x in anticeleb ]
anticeleb
# Out:
# ['LilTunechi',
#  'DojaCat',
#  'virgilabloh',
#  'shameikmoore',
#  'llcoolj',
#  'terrycrews']

# %%
woke=inp.split()
woke = [x if x[0]!="@" else x[1:] for x in woke ]
woke
# Out:
# ['Trevornoah',
#  'jameelajamil',
#  'EmmaWatson',
#  'Beyonce',
#  'johnlegend',
#  'chrissyteigen',
#  'KimKardashian',
#  'iJesseWilliams',
#  'KingJames',
#  'DwyaneWade',
#  'carmeloanthony',
#  'CP3',
#  'IssaRae',
#  'kanyewest',
#  'Kaepernick7',
#  'TyroneCarter954']

# %%
liberalmedia=inp.split()
liberalmedia = [x if x[0]!="@" else x[1:] for x in liberalmedia ]
liberalmedia
# Out:
# ['benyt',
#  'OmarJimenez',
#  'FareedZakaria',
#  'deanbaquet',
#  'alexisjreports',
#  'search4swag',
#  'ZoeTillman',
#  'kyledcheney',
#  'seungminkim',
#  'sahilkapur',
#  'jeneps']

# %%
celebrity=inp.split()
celebrity = [x if x[0]!="@" else x[1:] for x in celebrity ]
celebrity
# Out:
# ['adamlambert',
#  'AROD',
#  'JLo',
#  'ArianaGrande',
#  'bellahadid',
#  'Beyonce',
#  'billieeilish',
#  'blakelively',
#  'VancityReynolds',
#  'colesprouse',
#  'Drake',
#  'ImaanHammam',
#  'Doutzen',
#  'GiGiHadid',
#  'halsey',
#  'Harry_Styles',
#  'RossLynch',
#  'JazSinclair',
#  'joejonas',
#  'LaurenJauregui',
#  'lilireinhart',
#  'machinegunkelly',
#  'Madonna']

# %%
conservativemedia=inp.split()
conservativemedia = [x if x[0]!="@" else x[1:] for x in conservativemedia ]
conservativemedia
# Out:
# ['glennbeck',
#  'seanhannity',
#  'BretBaier',
#  'DanaPerino',
#  'benshapiro',
#  'michaeljknowles',
#  'RichLowry',
#  'kristina_wong']

# %%
protesters=inp.split()
protesters = [x if x[0]!="@" else x[1:] for x in protesters ]
protesters
# Out:
# ['OsopePatrisse',
#  'CharleneCac',
#  'aliciagarza',
#  'opalayo',
#  'JamilahLemieux',
#  'ProfessorCrunk',
#  'Nettaaaaaaaa',
#  'brownblaze',
#  'TheRevAl',
#  'jeremiah4north',
#  'kwamerose',
#  'AalayahEastmond',
#  'andreaforward8',
#  'nupol_justice',
#  'osse2021']

# %%
inp=input()
"""
@AOC
@CarterCenter
@BernieSanders
@JoeBiden
@KamalaHarris
@SenWarren
@RepCummings
@repjohnlewis
@HillaryClinton
@NYGovCuomo
@Mike_Pence
@JohnKerry
@RepMaxineWaters
@SpeakerPelosi
@MayorBowser
@MurielBowser
@Jacob_Frey
@GovTimWalz
@MayorHancock
@IlhanMN
@SenAmyKlobuchar
@SenTinaSmith
@andreajenkyns
@POTUS
@VP
@BarackObama


"""
# Out:
# @POTUS @VP @BarackObama
# '\n@AOC\n@CarterCenter\n@BernieSanders\n@JoeBiden\n@KamalaHarris\n@SenWarren\n@RepCummings\n@repjohnlewis\n@HillaryClinton\n@NYGovCuomo\n@Mike_Pence\n@JohnKerry\n@RepMaxineWaters\n@SpeakerPelosi\n@MayorBowser\n@MurielBowser\n@Jacob_Frey\n@GovTimWalz\n@MayorHancock\n@IlhanMN\n@SenAmyKlobuchar\n@SenTinaSmith\n@andreajenkyns\n@POTUS\n@VP\n@BarackObama\n\n\n'

# %%
nonantagonist=inp.split()
nonantagonist = [x if x[0]!="@" else x[1:] for x in nonantagonist ]
nonantagonist
# Out:
# ['POTUS', 'VP', 'BarackObama']

# %%
coords=defaultdict(lambda: defaultdict(list))
coords
# Out:
# defaultdict(<function __main__.<lambda>()>, {})

# %%
import time
for i in protesters:
    for j in nonantagonist:
        if i!=j and coords[i][j]==[]:
            print(i,j)
            status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            coords[i][j]=[status[0].following,
                        status[1].following,
                        status[0].followed_by,
                        status[1].followed_by
                        ]
        
            time.sleep(0.1)
        print(i,j,coords[i][j])
# Out:
# OsopePatrisse AOC
# OsopePatrisse AOC [True, True, True, True]
# OsopePatrisse CarterCenter
# OsopePatrisse CarterCenter [False, False, False, False]
# OsopePatrisse BernieSanders
# OsopePatrisse BernieSanders [True, True, True, True]
# OsopePatrisse JoeBiden
# OsopePatrisse JoeBiden [True, False, False, True]
# OsopePatrisse KamalaHarris
# OsopePatrisse KamalaHarris [True, False, False, True]
# OsopePatrisse SenWarren
# OsopePatrisse SenWarren [False, False, False, False]
# OsopePatrisse RepCummings
# OsopePatrisse RepCummings [False, False, False, False]
# OsopePatrisse repjohnlewis
# OsopePatrisse repjohnlewis [True, False, False, True]
# OsopePatrisse HillaryClinton
# OsopePatrisse HillaryClinton [False, False, False, False]
# OsopePatrisse NYGovCuomo
# OsopePatrisse NYGovCuomo [False, False, False, False]
# OsopePatrisse Mike_Pence
# OsopePatrisse Mike_Pence [False, False, False, False]
# OsopePatrisse JohnKerry
# OsopePatrisse JohnKerry [False, False, False, False]
# ...

# %%
np.save('coords', np.array(dict(coords)))

# %%
coords
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'OsopePatrisse': defaultdict(list,
#                          {'AOC': [True, True, True, True],
#                           'CarterCenter': [False, False, False, False],
#                           'BernieSanders': [True, True, True, True],
#                           'JoeBiden': [True, False, False, True],
#                           'KamalaHarris': [True, False, False, True],
#                           'SenWarren': [False, False, False, False],
#                           'RepCummings': [False, False, False, False],
#                           'repjohnlewis': [True, False, False, True],
#                           'HillaryClinton': [False, False, False, False],
#                           'NYGovCuomo': [False, False, False, False],
#                           'Mike_Pence': [False, False, False, False],
#                           'JohnKerry': [False, False, False, False],
# ...

# %%
coords[0]
# Out:
# defaultdict(list, {0: []})

# %%
file = open("sample.txt", "w")
str_dictionary = repr(coords)
file.write(str_dictionary + "\n")
file.close()

# %%
coords2=defaultdict(lambda: defaultdict(list))
coords2

# %%
inp=input()
"""
@realDonaldTrump
@jdanbishop
@Schwarzenegger
@SecretaryCarson
@tedcruz
@BorisJohnson
@RudyGiuliani
@GOPLeader
@SenatorTimScott
@RepJuanFBarquin
@GovRonDeSantis
@mtgreenee
@SaraJacobsCA
@RepMattGaetz
"""
# Out:
# @realDonaldTrump @jdanbishop @Schwarzenegger @SecretaryCarson @tedcruz @BorisJohnson @RudyGiuliani @GOPLeader @SenatorTimScott @RepJuanFBarquin @GovRonDeSantis @mtgreenee @SaraJacobsCA @RepMattGaetz
# '\n@realDonaldTrump\n@jdanbishop\n@Schwarzenegger\n@SecretaryCarson\n@tedcruz\n@BorisJohnson\n@RudyGiuliani\n@GOPLeader\n@SenatorTimScott\n@RepJuanFBarquin\n@GovRonDeSantis\n@mtgreenee\n@SaraJacobsCA\n@RepMattGaetz\n'

# %%
antagonist=inp.split()
antagonist = [x if x[0]!="@" else x[1:] for x in antagonist ]
antagonist
# Out:
# ['realDonaldTrump',
#  'jdanbishop',
#  'Schwarzenegger',
#  'SecretaryCarson',
#  'tedcruz',
#  'BorisJohnson',
#  'RudyGiuliani',
#  'GOPLeader',
#  'SenatorTimScott',
#  'RepJuanFBarquin',
#  'GovRonDeSantis',
#  'mtgreenee',
#  'SaraJacobsCA',
#  'RepMattGaetz']

# %%
protesters
# Out:
# ['OsopePatrisse',
#  'CharleneCac',
#  'aliciagarza',
#  'opalayo',
#  'JamilahLemieux',
#  'ProfessorCrunk',
#  'Nettaaaaaaaa',
#  'brownblaze',
#  'TheRevAl',
#  'jeremiah4north',
#  'kwamerose',
#  'AalayahEastmond',
#  'andreaforward8',
#  'nupol_justice',
#  'osse2021']

# %%
coordsant=defaultdict(lambda: defaultdict(list))
coordsant
# Out:
# defaultdict(<function __main__.<lambda>()>, {})

# %%
import time
for i in protesters:
    for j in antagonist:
        if i!=j and coordsant[i][j]==[]:
            print(i,j)
            status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            coordsant[i][j]=[status[0].following,
                        status[1].following,
                        status[0].followed_by,
                        status[1].followed_by
                        ]
        
            time.sleep(0.1)
        print(i,j,coordsant[i][j])
# Out:
# OsopePatrisse realDonaldTrump
# OsopePatrisse realDonaldTrump [False, False, False, False]
# OsopePatrisse jdanbishop
# OsopePatrisse jdanbishop [False, False, False, False]
# OsopePatrisse Schwarzenegger
# OsopePatrisse Schwarzenegger [False, False, False, False]
# OsopePatrisse SecretaryCarson
# OsopePatrisse SecretaryCarson [False, False, False, False]
# OsopePatrisse tedcruz
# OsopePatrisse tedcruz [False, False, False, False]
# OsopePatrisse BorisJohnson
# OsopePatrisse BorisJohnson [False, False, False, False]
# OsopePatrisse RudyGiuliani
# OsopePatrisse RudyGiuliani [False, False, False, False]
# OsopePatrisse GOPLeader
# OsopePatrisse GOPLeader [False, False, False, False]
# OsopePatrisse SenatorTimScott
# OsopePatrisse SenatorTimScott [False, False, False, False]
# OsopePatrisse RepJuanFBarquin
# OsopePatrisse RepJuanFBarquin [False, False, False, False]
# OsopePatrisse GovRonDeSantis
# OsopePatrisse GovRonDeSantis [False, False, False, False]
# OsopePatrisse mtgreenee
# ...

# %%
coordsant
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'OsopePatrisse': defaultdict(list,
#                          {'realDonaldTrump': [False, False, False, False],
#                           'jdanbishop': [False, False, False, False],
#                           'Schwarzenegger': [False, False, False, False],
#                           'SecretaryCarson': [False, False, False, False],
#                           'tedcruz': [False, False, False, False],
#                           'BorisJohnson': [False, False, False, False],
#                           'RudyGiuliani': [False, False, False, False],
#                           'GOPLeader': [False, False, False, False],
#                           'SenatorTimScott': [False, False, False, False],
#                           'RepJuanFBarquin': [False, False, False, False],
#                           'GovRonDeSantis': [False, False, False, False],
#                           'mtgreenee': [False, False, False, False],
# ...

# %%
savecoordsant=coordsant

# %%
savecoordsant
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'OsopePatrisse': defaultdict(list,
#                          {'realDonaldTrump': [False, False, False, False],
#                           'jdanbishop': [False, False, False, False],
#                           'Schwarzenegger': [False, False, False, False],
#                           'SecretaryCarson': [False, False, False, False],
#                           'tedcruz': [False, False, False, False],
#                           'BorisJohnson': [False, False, False, False],
#                           'RudyGiuliani': [False, False, False, False],
#                           'GOPLeader': [False, False, False, False],
#                           'SenatorTimScott': [False, False, False, False],
#                           'RepJuanFBarquin': [False, False, False, False],
#                           'GovRonDeSantis': [False, False, False, False],
#                           'mtgreenee': [False, False, False, False],
# ...

# %%
file = open("antagonist_sample.txt", "w")
str_dictionary_ant = repr(savecoordsant)
file.write(str_dictionary_ant + "\n")
file.close()

# %%
savecoordsant['CharleneCac']
# Out:
# defaultdict(list,
#             {'realDonaldTrump': [False, False, False, False],
#              'jdanbishop': [False, False, False, False],
#              'Schwarzenegger': [False, False, False, False],
#              'SecretaryCarson': [False, False, False, False],
#              'tedcruz': [False, False, False, False],
#              'BorisJohnson': [False, False, False, False],
#              'RudyGiuliani': [False, False, False, False],
#              'GOPLeader': [False, False, False, False],
#              'SenatorTimScott': [False, False, False, False],
#              'RepJuanFBarquin': [False, False, False, False],
#              'GovRonDeSantis': [False, False, False, False],
#              'mtgreenee': [False, False, False, False],
#              'SaraJacobsCA': [False, False, False, False],
#              'RepMattGaetz': [False, False, False, False]})

# %%
antTable=[]
for i in protesters:
    
    for j in antagonist:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        antTable.append(row)
    #matrix.append([0 for c in range(0, cols)])
# Out:
# OsopePatrisse realDonaldTrump ['OsopePatrisse', 'realDonaldTrump', False]
# OsopePatrisse jdanbishop ['OsopePatrisse', 'jdanbishop', False]
# OsopePatrisse Schwarzenegger ['OsopePatrisse', 'Schwarzenegger', False]
# OsopePatrisse SecretaryCarson ['OsopePatrisse', 'SecretaryCarson', False]
# OsopePatrisse tedcruz ['OsopePatrisse', 'tedcruz', False]
# OsopePatrisse BorisJohnson ['OsopePatrisse', 'BorisJohnson', False]
# OsopePatrisse RudyGiuliani ['OsopePatrisse', 'RudyGiuliani', False]
# OsopePatrisse GOPLeader ['OsopePatrisse', 'GOPLeader', False]
# OsopePatrisse SenatorTimScott ['OsopePatrisse', 'SenatorTimScott', False]
# OsopePatrisse RepJuanFBarquin ['OsopePatrisse', 'RepJuanFBarquin', False]
# OsopePatrisse GovRonDeSantis ['OsopePatrisse', 'GovRonDeSantis', False]
# OsopePatrisse mtgreenee ['OsopePatrisse', 'mtgreenee', False]
# OsopePatrisse SaraJacobsCA ['OsopePatrisse', 'SaraJacobsCA', False]
# OsopePatrisse RepMattGaetz ['OsopePatrisse', 'RepMattGaetz', False]
# ...

# %%
antTable
# Out:
# [['OsopePatrisse', 'realDonaldTrump', False],
#  ['OsopePatrisse', 'jdanbishop', False],
#  ['OsopePatrisse', 'Schwarzenegger', False],
#  ['OsopePatrisse', 'SecretaryCarson', False],
#  ['OsopePatrisse', 'tedcruz', False],
#  ['OsopePatrisse', 'BorisJohnson', False],
#  ['OsopePatrisse', 'RudyGiuliani', False],
#  ['OsopePatrisse', 'GOPLeader', False],
#  ['OsopePatrisse', 'SenatorTimScott', False],
#  ['OsopePatrisse', 'RepJuanFBarquin', False],
#  ['OsopePatrisse', 'GovRonDeSantis', False],
#  ['OsopePatrisse', 'mtgreenee', False],
#  ['OsopePatrisse', 'SaraJacobsCA', False],
#  ['OsopePatrisse', 'RepMattGaetz', False],
#  ['CharleneCac', 'realDonaldTrump', False],
#  ['CharleneCac', 'jdanbishop', False],
#  ['CharleneCac', 'Schwarzenegger', False],
#  ['CharleneCac', 'SecretaryCarson', False],
#  ['CharleneCac', 'tedcruz', False],
#  ['CharleneCac', 'BorisJohnson', False],
#  ['CharleneCac', 'RudyGiuliani', False],
#  ['CharleneCac', 'GOPLeader', False],
# ...

# %%
for i in antagonist:
    
    for j in protesters:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        antTable.append(row)
# Out:
# realDonaldTrump OsopePatrisse ['realDonaldTrump', 'OsopePatrisse', False]
# realDonaldTrump CharleneCac ['realDonaldTrump', 'CharleneCac', False]
# realDonaldTrump aliciagarza ['realDonaldTrump', 'aliciagarza', False]
# realDonaldTrump opalayo ['realDonaldTrump', 'opalayo', False]
# realDonaldTrump JamilahLemieux ['realDonaldTrump', 'JamilahLemieux', False]
# realDonaldTrump ProfessorCrunk ['realDonaldTrump', 'ProfessorCrunk', False]
# realDonaldTrump Nettaaaaaaaa ['realDonaldTrump', 'Nettaaaaaaaa', False]
# realDonaldTrump brownblaze ['realDonaldTrump', 'brownblaze', False]
# realDonaldTrump TheRevAl ['realDonaldTrump', 'TheRevAl', False]
# realDonaldTrump jeremiah4north ['realDonaldTrump', 'jeremiah4north', False]
# realDonaldTrump kwamerose ['realDonaldTrump', 'kwamerose', False]
# realDonaldTrump AalayahEastmond ['realDonaldTrump', 'AalayahEastmond', False]
# realDonaldTrump andreaforward8 ['realDonaldTrump', 'andreaforward8', False]
# ...

# %%
antTable
# Out:
# [['OsopePatrisse', 'realDonaldTrump', False],
#  ['OsopePatrisse', 'jdanbishop', False],
#  ['OsopePatrisse', 'Schwarzenegger', False],
#  ['OsopePatrisse', 'SecretaryCarson', False],
#  ['OsopePatrisse', 'tedcruz', False],
#  ['OsopePatrisse', 'BorisJohnson', False],
#  ['OsopePatrisse', 'RudyGiuliani', False],
#  ['OsopePatrisse', 'GOPLeader', False],
#  ['OsopePatrisse', 'SenatorTimScott', False],
#  ['OsopePatrisse', 'RepJuanFBarquin', False],
#  ['OsopePatrisse', 'GovRonDeSantis', False],
#  ['OsopePatrisse', 'mtgreenee', False],
#  ['OsopePatrisse', 'SaraJacobsCA', False],
#  ['OsopePatrisse', 'RepMattGaetz', False],
#  ['CharleneCac', 'realDonaldTrump', False],
#  ['CharleneCac', 'jdanbishop', False],
#  ['CharleneCac', 'Schwarzenegger', False],
#  ['CharleneCac', 'SecretaryCarson', False],
#  ['CharleneCac', 'tedcruz', False],
#  ['CharleneCac', 'BorisJohnson', False],
#  ['CharleneCac', 'RudyGiuliani', False],
#  ['CharleneCac', 'GOPLeader', False],
# ...

# %%
import pandas as pd 

df = pd.DataFrame(antTable, columns = ['Source', 'Target','Follows']) 
 
print(df )
# Out:
#             Source           Target  Follows
# 0    OsopePatrisse  realDonaldTrump    False
# 1    OsopePatrisse       jdanbishop    False
# 2    OsopePatrisse   Schwarzenegger    False
# 3    OsopePatrisse  SecretaryCarson    False
# 4    OsopePatrisse          tedcruz    False
# ..             ...              ...      ...
# 415   RepMattGaetz        kwamerose    False
# 416   RepMattGaetz  AalayahEastmond    False
# 417   RepMattGaetz   andreaforward8    False
# 418   RepMattGaetz    nupol_justice    False
# 419   RepMattGaetz         osse2021    False
#
# [420 rows x 3 columns]

# %%
df.to_csv('antagonistsTable.csv')

# %%
nonantTable=[]
for i in protesters:
    
    for j in nonantagonist:
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            row.append(status[0].following)
        
            time.sleep(0.1)
        print(i,j,row)
        nonantTable.append(row)
    #matrix.append([0 for c in range(0, cols)])
# Out:
# OsopePatrisse AOC ['OsopePatrisse', 'AOC', True]
# OsopePatrisse CarterCenter ['OsopePatrisse', 'CarterCenter', False]
# OsopePatrisse BernieSanders ['OsopePatrisse', 'BernieSanders', True]
# OsopePatrisse JoeBiden ['OsopePatrisse', 'JoeBiden', True]
# OsopePatrisse KamalaHarris ['OsopePatrisse', 'KamalaHarris', True]
# OsopePatrisse SenWarren ['OsopePatrisse', 'SenWarren', False]
# OsopePatrisse RepCummings ['OsopePatrisse', 'RepCummings', False]
# OsopePatrisse repjohnlewis ['OsopePatrisse', 'repjohnlewis', True]
# OsopePatrisse HillaryClinton ['OsopePatrisse', 'HillaryClinton', False]
# OsopePatrisse NYGovCuomo ['OsopePatrisse', 'NYGovCuomo', False]
# OsopePatrisse Mike_Pence ['OsopePatrisse', 'Mike_Pence', False]
# OsopePatrisse JohnKerry ['OsopePatrisse', 'JohnKerry', False]
# OsopePatrisse RepMaxineWaters ['OsopePatrisse', 'RepMaxineWaters', True]
# OsopePatrisse SpeakerPelosi ['OsopePatrisse', 'SpeakerPelosi', False]
# ...

# %%
for i in nonantagonist:
    
    for j in protesters:
        print(i,j)
        row=[]
        row.append(i)
        if i!=j:
            row.append(j)
            try:
                status = api.show_friendship(source_screen_name = i,target_screen_name = j)
            
                row.append(status[0].following)
            except tweepy.error.TweepError:
                print("user not found")
            time.sleep(0.1)
        print(i,j,row)
        nonantTable.append(row)
# Out:
# AOC OsopePatrisse
# user not found
# AOC OsopePatrisse ['AOC', 'OsopePatrisse']
# AOC CharleneCac
# AOC CharleneCac ['AOC', 'CharleneCac', False]
# AOC aliciagarza
# AOC aliciagarza ['AOC', 'aliciagarza', True]
# AOC opalayo
# AOC opalayo ['AOC', 'opalayo', True]
# AOC JamilahLemieux
# AOC JamilahLemieux ['AOC', 'JamilahLemieux', True]
# AOC ProfessorCrunk
# AOC ProfessorCrunk ['AOC', 'ProfessorCrunk', True]
# AOC Nettaaaaaaaa
# AOC Nettaaaaaaaa ['AOC', 'Nettaaaaaaaa', False]
# AOC brownblaze
# AOC brownblaze ['AOC', 'brownblaze', True]
# AOC TheRevAl
# AOC TheRevAl ['AOC', 'TheRevAl', False]
# AOC jeremiah4north
# AOC jeremiah4north ['AOC', 'jeremiah4north', False]
# AOC kwamerose
# AOC kwamerose ['AOC', 'kwamerose', False]
# AOC AalayahEastmond
# AOC AalayahEastmond ['AOC', 'AalayahEastmond', False]
# AOC andreaforward8
# AOC andreaforward8 ['AOC', 'andreaforward8', False]
# AOC nupol_justice
# AOC nupol_justice ['AOC', 'nupol_justice', True]
# AOC osse2021
# ...

# %%
nonantTable
# Out:
# [['OsopePatrisse', 'AOC', True],
#  ['OsopePatrisse', 'CarterCenter', False],
#  ['OsopePatrisse', 'BernieSanders', True],
#  ['OsopePatrisse', 'JoeBiden', True],
#  ['OsopePatrisse', 'KamalaHarris', True],
#  ['OsopePatrisse', 'SenWarren', False],
#  ['OsopePatrisse', 'RepCummings', False],
#  ['OsopePatrisse', 'repjohnlewis', True],
#  ['OsopePatrisse', 'HillaryClinton', False],
#  ['OsopePatrisse', 'NYGovCuomo', False],
#  ['OsopePatrisse', 'Mike_Pence', False],
#  ['OsopePatrisse', 'JohnKerry', False],
#  ['OsopePatrisse', 'RepMaxineWaters', True],
#  ['OsopePatrisse', 'SpeakerPelosi', False],
#  ['OsopePatrisse', 'MayorBowser', False],
#  ['OsopePatrisse', 'MurielBowser', False],
#  ['OsopePatrisse', 'Jacob_Frey', False],
#  ['OsopePatrisse', 'GovTimWalz', False],
#  ['OsopePatrisse', 'MayorHancock', False],
#  ['OsopePatrisse', 'IlhanMN', True],
#  ['OsopePatrisse', 'SenAmyKlobuchar', False],
#  ['OsopePatrisse', 'SenTinaSmith', False],
# ...

# %%
df2 = pd.DataFrame(nonantTable, columns = ['Source', 'Target','Follows']) 
 
print(df2 )
# Out:
#             Source           Target Follows
# 0    OsopePatrisse              AOC    True
# 1    OsopePatrisse     CarterCenter   False
# 2    OsopePatrisse    BernieSanders    True
# 3    OsopePatrisse         JoeBiden    True
# 4    OsopePatrisse     KamalaHarris    True
# ..             ...              ...     ...
# 685  andreajenkyns        kwamerose   False
# 686  andreajenkyns  AalayahEastmond   False
# 687  andreajenkyns   andreaforward8   False
# 688  andreajenkyns    nupol_justice   False
# 689  andreajenkyns         osse2021   False
#
# [690 rows x 3 columns]

# %%
df2.to_csv('NonantagonistsTable.csv')
